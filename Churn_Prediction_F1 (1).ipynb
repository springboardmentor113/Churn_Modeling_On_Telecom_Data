# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
# %matplotlib inline

# %%
df = pd.read_csv('Churn_ Data.csv')
df.shape
# Out:
# (25000, 111)

# %%
df.head()
# Out:
#    s6.new.rev.p2.m2  s1.new.rev.m1  s3.og.rev.4db.p5  s3.new.rev.4db.p5  \
# 0             -0.76        88.0482          3.106604           3.754955
# 1             -0.98        67.5039          3.094574           5.550865
# 2             -0.98        33.9248          2.324016           2.438114
# 3             -0.92        82.6780          2.630749           2.858961
# 4             -0.97        96.8379          2.674316           2.912397
#
#    s4.usg.ins.p2  s4.og.unq.any.p2  s2.rch.val.p6  s1.og.rev.all.m1  \
# 0              4                14          39.29            57.320
# 1              1                 2          21.67            38.700
# 2              2                 3          30.00            15.320
# 3              2                 3          50.00            51.956
# 4              3                 2          22.50            66.886
#
#    s8.new.rev.p6  s4.loc.ic.ins.p1  ...  prop.og.mou.tot.mou.all.p6  \
# ...

# %%
df.tail()
# Out:
#        s6.new.rev.p2.m2  s1.new.rev.m1  s3.og.rev.4db.p5  s3.new.rev.4db.p5  \
# 24995              0.21       132.0365          2.652236           2.857739
# 24996              0.80        77.0154          3.763389           5.012503
# 24997              0.01       148.8337          3.823940           4.334250
# 24998              0.17      1012.4398         14.667580          14.579567
# 24999             -1.00       275.3530          5.134579           5.954062
#
#        s4.usg.ins.p2  s4.og.unq.any.p2  s2.rch.val.p6  s1.og.rev.all.m1  \
# 24995              5                 8          26.67           123.396
# 24996              2                 8          27.88            62.140
# 24997              6                10          10.00            98.900
# 24998              7                67          42.92           734.005
# 24999              1                 1          53.50           250.340
#
#        s8.new.rev.p6  s4.loc.ic.ins.p1  ...  prop.og.mou.tot.mou.all.p6  \
# ...

# %%
df.size
# Out:
# 2775000

# %%
df.dtypes
# Out:
# s6.new.rev.p2.m2              float64
# s1.new.rev.m1                 float64
# s3.og.rev.4db.p5              float64
# s3.new.rev.4db.p5             float64
# s4.usg.ins.p2                   int64
#                                ...
# s3.og.rev.all.m2              float64
# s3.new.rev.m2                 float64
# prop.og.mou.any.p6            float64
# prop.loc.i2i.mou.og.mou.p3    float64
# s3.rev.p1                     float64
# Length: 111, dtype: object

# %%
df.columns
# Out:
# Index(['s6.new.rev.p2.m2', 's1.new.rev.m1', 's3.og.rev.4db.p5',
#        's3.new.rev.4db.p5', 's4.usg.ins.p2', 's4.og.unq.any.p2',
#        's2.rch.val.p6', 's1.og.rev.all.m1', 's8.new.rev.p6',
#        's4.loc.ic.ins.p1',
#        ...
#        'prop.og.mou.tot.mou.all.p6', 'prop.i2i.og.mou.p6', 's4.loc.ic.ins.p2',
#        's4.std.ic.ins.l14', 's4.low.blnc.ins.p4', 's3.og.rev.all.m2',
#        's3.new.rev.m2', 'prop.og.mou.any.p6', 'prop.loc.i2i.mou.og.mou.p3',
#        's3.rev.p1'],
#       dtype='object', length=111)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Columns: 111 entries, s6.new.rev.p2.m2 to s3.rev.p1
# dtypes: float64(80), int64(31)
# memory usage: 21.2 MB

# %%
 df_num = df.select_dtypes(np.number)

# %%
df_num
# Out:
#        s6.new.rev.p2.m2  s1.new.rev.m1  s3.og.rev.4db.p5  s3.new.rev.4db.p5  \
# 0                 -0.76        88.0482          3.106604           3.754955
# 1                 -0.98        67.5039          3.094574           5.550865
# 2                 -0.98        33.9248          2.324016           2.438114
# 3                 -0.92        82.6780          2.630749           2.858961
# 4                 -0.97        96.8379          2.674316           2.912397
# ...                 ...            ...               ...                ...
# 24995              0.21       132.0365          2.652236           2.857739
# 24996              0.80        77.0154          3.763389           5.012503
# 24997              0.01       148.8337          3.823940           4.334250
# 24998              0.17      1012.4398         14.667580          14.579567
# 24999             -1.00       275.3530          5.134579           5.954062
#
# ...

# %%
df.isnull().sum()
# Out:
# s6.new.rev.p2.m2              0
# s1.new.rev.m1                 0
# s3.og.rev.4db.p5              0
# s3.new.rev.4db.p5             0
# s4.usg.ins.p2                 0
#                              ..
# s3.og.rev.all.m2              0
# s3.new.rev.m2                 0
# prop.og.mou.any.p6            0
# prop.loc.i2i.mou.og.mou.p3    0
# s3.rev.p1                     0
# Length: 111, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.skew(numeric_only = True)
# Out:
# s6.new.rev.p2.m2              89.183151
# s1.new.rev.m1                  2.901020
# s3.og.rev.4db.p5               4.782838
# s3.new.rev.4db.p5              4.716058
# s4.usg.ins.p2                 -1.359001
#                                 ...
# s3.og.rev.all.m2               3.784480
# s3.new.rev.m2                  6.147159
# prop.og.mou.any.p6            -0.125573
# prop.loc.i2i.mou.og.mou.p3     0.051543
# s3.rev.p1                      7.652766
# Length: 111, dtype: float64

# %%
df.corr(numeric_only = True)
# Out:
#                             s6.new.rev.p2.m2  s1.new.rev.m1  s3.og.rev.4db.p5  \
# s6.new.rev.p2.m2                    1.000000      -0.006593          0.003140
# s1.new.rev.m1                      -0.006593       1.000000          0.500320
# s3.og.rev.4db.p5                    0.003140       0.500320          1.000000
# s3.new.rev.4db.p5                   0.022883       0.528649          0.685506
# s4.usg.ins.p2                       0.121748       0.237449          0.065918
# ...                                      ...            ...               ...
# s3.og.rev.all.m2                   -0.035846       0.543201          0.918249
# s3.new.rev.m2                      -0.032196       0.526472          0.489969
# prop.og.mou.any.p6                  0.018634       0.225228          0.225717
# prop.loc.i2i.mou.og.mou.p3          0.019545       0.007068         -0.066550
# s3.rev.p1                           0.072737       0.254520          0.250023
#
# ...

# %%
df.describe()
# Out:
#        s6.new.rev.p2.m2  s1.new.rev.m1  s3.og.rev.4db.p5  s3.new.rev.4db.p5  \
# count      25000.000000   25000.000000      25000.000000       25000.000000
# mean          -0.003730     281.073083          4.890003           7.070194
# std            2.727916     276.075983          4.212452           6.318992
# min           -1.000000       0.000000          0.000000           0.000833
# 25%           -0.580000     101.563800          2.367288           3.318825
# 50%           -0.170000     204.859600          3.729944           5.231268
# 75%            0.280000     370.711650          5.993342           8.395736
# max          316.860000    5702.924300        153.221695         170.200441
#
#        s4.usg.ins.p2  s4.og.unq.any.p2  s2.rch.val.p6  s1.og.rev.all.m1  \
# count   25000.000000      25000.000000   25000.000000      25000.000000
# mean        5.460080         28.532520      72.208906        218.517937
# ...

# %%
z_var = []
for col in df.columns:
    var = df[col].var()
    if var == 0:
        z_var.append(col)
        
if z_var:
    print("The columns having zero variance are : " + z_var)
    df.drop(columns = z_var , inplace = True)
    
else :
    print("There are no zero variance columns found...")
# Out:
# There are no zero variance columns found...

# %%
uni_val = df.nunique()
print(uni_val)
# Out:
# s6.new.rev.p2.m2                584
# s1.new.rev.m1                 24134
# s3.og.rev.4db.p5              24969
# s3.new.rev.4db.p5             24980
# s4.usg.ins.p2                     8
#                               ...
# s3.og.rev.all.m2               2716
# s3.new.rev.m2                  3860
# prop.og.mou.any.p6            24819
# prop.loc.i2i.mou.og.mou.p3    23102
# s3.rev.p1                      3904
# Length: 111, dtype: int64

# %%
for i in df.columns :
    print("Number of unique values in {} \n The unique values are {} ".format(i,len(df[i].unique()),df[i].unique()))
    print("----------------------------------------------------\n")
# Out:
# Number of unique values in s6.new.rev.p2.m2
#  The unique values are 584
# ----------------------------------------------------
#
# Number of unique values in s1.new.rev.m1
#  The unique values are 24134
# ----------------------------------------------------
#
# Number of unique values in s3.og.rev.4db.p5
#  The unique values are 24969
# ----------------------------------------------------
#
# Number of unique values in s3.new.rev.4db.p5
#  The unique values are 24980
# ----------------------------------------------------
#
# Number of unique values in s4.usg.ins.p2
#  The unique values are 8
# ----------------------------------------------------
#
# Number of unique values in s4.og.unq.any.p2
#  The unique values are 213
# ----------------------------------------------------
#
# Number of unique values in s2.rch.val.p6
#  The unique values are 6231
# ----------------------------------------------------
#
# Number of unique values in s1.og.rev.all.m1
#  The unique values are 22744
# ...

# %%
plt.figure(figsize = (12,8))
df.boxplot()
plt.show()

# %%
df.columns
# Out:
# Index(['s6.new.rev.p2.m2', 's1.new.rev.m1', 's3.og.rev.4db.p5',
#        's3.new.rev.4db.p5', 's4.usg.ins.p2', 's4.og.unq.any.p2',
#        's2.rch.val.p6', 's1.og.rev.all.m1', 's8.new.rev.p6',
#        's4.loc.ic.ins.p1',
#        ...
#        'prop.og.mou.tot.mou.all.p6', 'prop.i2i.og.mou.p6', 's4.loc.ic.ins.p2',
#        's4.std.ic.ins.l14', 's4.low.blnc.ins.p4', 's3.og.rev.all.m2',
#        's3.new.rev.m2', 'prop.og.mou.any.p6', 'prop.loc.i2i.mou.og.mou.p3',
#        's3.rev.p1'],
#       dtype='object', length=111)

# %%
 def outlier(col):
    q1,q3 = np.percentile(col,[25,75])
    iqr = q3-q1
    lw = q1-1.5*iqr
    uw = q3+1.5*iqr
    return lw,uw

# %%
 outlier(df['s3.new.rev.4db.p5'])
# Out:
# (-4.296540105125002, 16.011101315875003)

# %%
data = df.columns
for i in data:
    lw,uw = outlier(df[i])
    df[i] = np.where(df[i] < lw,lw,df[i])
    df[i] = np.where(df[i] > uw,uw,df[i])

# %%
plt.figure(figsize = (12,8))
df.boxplot()
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.heatmap(df.corr(), cmap = 'coolwarm', vmin = -1 , vmax = 1);

# %%
def correlated_feature_pairs(dataset, threshold):
    correlated_pairs = []
    corr_matrix = dataset.corr()
    
    for i in range(len(corr_matrix.columns)):
        for j in range (i):
            if abs(corr_matrix.iloc[i,j]) > threshold:
                feature1 = corr_matrix.columns[i]
                feature2 = corr_matrix.columns[j]
                correlated_pairs.append((feature1,feature2))
                
    return correlated_pairs


correlation_threshold = 0.9

correlated_pairs = correlated_feature_pairs(df , correlation_threshold)

print("Total",len(correlated_pairs),"correlated pairs found...")
print(" ")

for pair in correlated_pairs:
    print(f"Correlated Pair : {pair[0]} and {pair[1]}")
# Out:
# Total 133 correlated pairs found...
#
# Correlated Pair : s1.og.rev.all.m1 and s1.new.rev.m1
# Correlated Pair : s2.rch.val.l67 and s2.rch.val.p6
# Correlated Pair : s7.new.rev.p2.p6 and s6.new.rev.p2.m2
# Correlated Pair : s7.rtd.mou.p2.p6 and s6.rtd.mou.p2.m2
# Correlated Pair : s1.new.rev.p1 and s1.new.rev.p2
# Correlated Pair : s1.rtd.mou.p1 and s1.og.hom.mou.p1
# Correlated Pair : s1.og.rev.all.p1 and s1.new.rev.p1
# Correlated Pair : s1.og.rev.all.p1 and s1.og.hom.rev.p2
# Correlated Pair : s1.og.mou.all.p1 and s1.og.hom.mou.p1
# Correlated Pair : s1.og.mou.all.p1 and s1.rtd.mou.p1
# Correlated Pair : snd.dec.p2 and s1.new.rev.p2
# Correlated Pair : snd.dec.p2 and s1.og.hom.rev.p2
# Correlated Pair : snd.dec.p2 and s1.og.rev.all.p1
# Correlated Pair : s1.og.mou.all.p2 and s1.og.hom.mou.p1
# Correlated Pair : s1.og.mou.all.p2 and s1.rtd.mou.p1
# Correlated Pair : s1.og.mou.all.p2 and s1.og.mou.all.p1
# Correlated Pair : s8.og.rev.p6 and s8.new.rev.p6
# ...

# %%
def correlation_removal(dataset, threshold):
    col_corr = set()
    correlated_pairs = []
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j]) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
df1 = df.copy()

# %%
correlated_features = correlation_removal(df1, 0.9)
len(set(correlated_features))
# Out:
# 55

# %%
correlated_features
# Out:
# {'prop.i2i.og.mou.p6',
#  'prop.og.mou.any.p6',
#  'prop.og.mou.tot.mou.all.p2',
#  's1.hom.rmg.rev.p2',
#  's1.loc.og.mou.p2',
#  's1.new.rev.p1',
#  's1.og.hom.mou.p2',
#  's1.og.mou.all.p1',
#  's1.og.mou.all.p2',
#  's1.og.mou.any.p2',
#  's1.og.rev.all.m1',
#  's1.og.rev.all.p1',
#  's1.og.rev.all.p2',
#  's1.rev.p1',
#  's1.rev.p2',
#  's1.rtd.mou.p1',
#  's1.rtd.mou.p2',
#  's2.rch.val.l67',
#  's2.s4.day.no.mou.p2',
#  's3.new.rev.m2',
#  's3.new.rev.p2',
#  's3.og.hom.mou.p1',
#  's3.og.rev.3db.p5',
#  's3.og.rev.all.m2',
#  's3.rev.p1',
#  's3.rtd.mou.p1',
#  's4.dec.ins.p2',
#  's4.loc.ic.ins.p2',
#  's4.loc.og.ins.p2',
#  's4.low.blnc.ins.l14',
#  's4.low.blnc.ins.m2',
#  's4.low.blnc.ins.p2',
#  's4.low.blnc.ins.p4',
#  's4.og.any.p2',
#  's4.std.ic.ins.l14',
#  's4.usg.ins.l14',
#  's4.usg.ins.p1',
#  's5.new.rev.p1',
#  's5.new.rev.p2',
#  's5.og.hom.mou.p1',
#  's5.og.hom.mou.p2',
#  's5.og.mou.all.p1',
#  's5.og.mou.all.p2',
#  's5.og.rev.all.p1',
# ...

# %%
df1.drop(correlated_features, axis = 1, inplace = True)

# %%
df1.shape[1]
# Out:
# 56

# %%
plt.figure(figsize = (10,8))
sns.heatmap(df1.corr(), cmap = 'coolwarm', vmin = -1 , vmax = 1);

# %%
correlated_pairs = correlated_feature_pairs(df1 , correlation_threshold)

print("Total",len(correlated_pairs),"correlated pairs found...")
print(" ")

for pair in correlated_pairs:
    print(f"Correlated Pair : {pair[0]} and {pair[1]}")
# Out:
# Total 0 correlated pairs found...

# %%
df1.head()
# Out:
#    s6.new.rev.p2.m2  s1.new.rev.m1  s3.og.rev.4db.p5  s3.new.rev.4db.p5  \
# 0             -0.76        88.0482          3.106604           3.754955
# 1             -0.98        67.5039          3.094574           5.550865
# 2             -0.98        33.9248          2.324016           2.438114
# 3             -0.92        82.6780          2.630749           2.858961
# 4             -0.97        96.8379          2.674316           2.912397
#
#    s4.usg.ins.p2  s4.og.unq.any.p2  s2.rch.val.p6  s8.new.rev.p6  \
# 0            4.0              14.0          39.29          -0.17
# 1            2.0               2.0          21.67          -0.32
# 2            2.0               3.0          30.00          -0.05
# 3            2.0               3.0          50.00          -0.18
# 4            3.0               2.0          22.50           0.01
#
#    s4.loc.ic.ins.p1  s8.mbl.p2  ...  s5.rev.p2  s1.new.rev.m2  \
# 0               1.5      -0.72  ...       7.04       295.1889
# ...

# %%
df1.shape
# Out:
# (25000, 56)

# %%
df1.columns
# Out:
# Index(['s6.new.rev.p2.m2', 's1.new.rev.m1', 's3.og.rev.4db.p5',
#        's3.new.rev.4db.p5', 's4.usg.ins.p2', 's4.og.unq.any.p2',
#        's2.rch.val.p6', 's8.new.rev.p6', 's4.loc.ic.ins.p1', 's8.mbl.p2',
#        's7.s4.day.no.mou.p2.p4', 's3.new.rev.p3', 's7.s5.s4.day.nomou.p4',
#        's8.og.rev.p3', 's8.ic.mou.all.p3', 'target', 's6.rtd.mou.p2.m2',
#        's1.new.rev.p2', 's1.og.hom.mou.p1', 's7.rev.p2.p6', 's1.og.hom.rev.p2',
#        's3.og.rev.all.p1', 's7.new.rev.p3.p6', 'ds.usg.p6', 's3.og.mou.all.p1',
#        'ds.og.usg.p4', 's4.day.no.mou.p2', 's7.rtd.mou.p3.p6', 's3.new.rev.p1',
#        's7.new.rev.l21.p6', 's5.rev.p1', 's8.new.rev.p3', 's3.og.mou.all.p2',
#        's4.loc.og.ins.p1', 's1.loc.og.mou.p1', 'prop.og.mou.any.p2',
#        's4.low.blnc.ins.p3', 's7.rtd.mou.l21.p6', 's4.loc.og.ins.l14',
#        's8.rtd.mou.p3', 's4.dec.ins.l14', 's2.s4.day.no.mou.p3',
#        's4.loc.ic.ins.l14', 's8.og.mou.all.p6', 's7.rtd.mou.m1.m2',
# ...

# %%
x = df1[['s6.new.rev.p2.m2', 's1.new.rev.m1', 's3.og.rev.4db.p5',
       's3.new.rev.4db.p5', 's4.usg.ins.p2', 's4.og.unq.any.p2',
       's2.rch.val.p6', 's8.new.rev.p6', 's4.loc.ic.ins.p1', 's8.mbl.p2',
       's7.s4.day.no.mou.p2.p4', 's3.new.rev.p3', 's7.s5.s4.day.nomou.p4',
       's8.og.rev.p3', 's8.ic.mou.all.p3' , 's6.rtd.mou.p2.m2',
       's1.new.rev.p2', 's1.og.hom.mou.p1', 's7.rev.p2.p6', 's1.og.hom.rev.p2',
       's3.og.rev.all.p1', 's7.new.rev.p3.p6', 'ds.usg.p6', 's3.og.mou.all.p1',
       'ds.og.usg.p4', 's4.day.no.mou.p2', 's7.rtd.mou.p3.p6', 's3.new.rev.p1',
       's7.new.rev.l21.p6', 's5.rev.p1', 's8.new.rev.p3', 's3.og.mou.all.p2',
       's4.loc.og.ins.p1', 's1.loc.og.mou.p1', 'prop.og.mou.any.p2',
       's4.low.blnc.ins.p3', 's7.rtd.mou.l21.p6', 's4.loc.og.ins.l14',
       's8.rtd.mou.p3', 's4.dec.ins.l14', 's2.s4.day.no.mou.p3',
       's4.loc.ic.ins.l14', 's8.og.mou.all.p6', 's7.rtd.mou.m1.m2',
       's8.rev.p6', 's5.rev.p2', 's1.new.rev.m2', 's4.rch.val.gt.30.p2',
       's4.std.ins.l14', 's4.low.blnc.ins.p6', 's4.loc.ins.l14',
       's4.data.ins.l14', 'prop.loc.i2i.mou.og.mou.p6',
       'prop.og.mou.tot.mou.all.p6', 'prop.loc.i2i.mou.og.mou.p3']]

# %%
y = df1['target']
y
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        0.0
# 4        0.0
#         ...
# 24995    1.0
# 24996    0.0
# 24997    0.0
# 24998    0.0
# 24999    1.0
# Name: target, Length: 25000, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state = 42)

# %%
x_train
# Out:
#        s6.new.rev.p2.m2  s1.new.rev.m1  s3.og.rev.4db.p5  s3.new.rev.4db.p5  \
# 23311              1.57       323.2568          0.288583          16.011101
# 23623              0.45       355.9698          4.135327           4.244594
# 1020               0.07       363.2173          1.051788           3.106174
# 12645             -0.97         9.3032          0.809547           1.255660
# 1533               0.99       209.8555          4.949858           4.978395
# ...                 ...            ...               ...                ...
# 21575              0.13       431.8553         11.432423          16.011101
# 5390               0.85         0.0000          2.359125           2.999531
# 860               -0.54       127.6495          4.712497           4.875921
# 15795              0.46       236.7235          1.351566           1.513962
# 23654              0.58       122.1891          1.897986           3.504762
#
# ...

# %%
y_train
# Out:
# 23311    0.0
# 23623    0.0
# 1020     0.0
# 12645    0.0
# 1533     0.0
#         ...
# 21575    0.0
# 5390     0.0
# 860      1.0
# 15795    0.0
# 23654    0.0
# Name: target, Length: 20000, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier
clf_entropy = DecisionTreeClassifier(criterion = 'entropy' , max_depth = 3 , random_state = 0)
clf_entropy.fit(x_train,y_train)
y_pred_entropy = clf_entropy.predict(x_test)

# %%
y_pred_entropy
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred_entropy))
# Out:
# 0.795

# %%
from sklearn import tree
plt.figure(figsize = (10,10))
tree.plot_tree(clf_entropy.fit(x_train,y_train))
plt.show()
