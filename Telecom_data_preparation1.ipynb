# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df = pd.read_csv("C:/Users/HP/Downloads/Churn_ Data.csv")
df.head()
# Out:
#    s6.new.rev.p2.m2  s1.new.rev.m1  s3.og.rev.4db.p5  s3.new.rev.4db.p5  \
# 0             -0.76        88.0482          3.106604           3.754955
# 1             -0.98        67.5039          3.094574           5.550865
# 2             -0.98        33.9248          2.324016           2.438114
# 3             -0.92        82.6780          2.630749           2.858961
# 4             -0.97        96.8379          2.674316           2.912397
#
#    s4.usg.ins.p2  s4.og.unq.any.p2  s2.rch.val.p6  s1.og.rev.all.m1  \
# 0              4                14          39.29            57.320
# 1              1                 2          21.67            38.700
# 2              2                 3          30.00            15.320
# 3              2                 3          50.00            51.956
# 4              3                 2          22.50            66.886
#
#    s8.new.rev.p6  s4.loc.ic.ins.p1  ...  prop.og.mou.tot.mou.all.p6  \
# 0          -0.17                 1  ...                    0.454642
# 1          -0.32                 3  ...                    0.343190
# 2          -0.05                 3  ...                    0.101838
# 3          -0.18                 4  ...                    0.066602
# 4           0.01                 4  ...                    0.219821
#
#    prop.i2i.og.mou.p6  s4.loc.ic.ins.p2  s4.std.ic.ins.l14  \
# 0            0.497397                 4                  0
# 1            0.767617                 6                  0
# 2            0.619034                 6                  1
# 3            0.437088                 7                  2
# 4            0.585977                 6                  1
#
#    s4.low.blnc.ins.p4  s3.og.rev.all.m2  s3.new.rev.m2  prop.og.mou.any.p6  \
# 0                   9              6.02           8.20           46.465636
# 1                  20              3.66           8.10           34.525456
# 2                  19              4.33           4.36           10.298451
# 3                  11              3.40           3.53            6.670783
# 4                  14              3.85           3.87           21.998905
#
#    prop.loc.i2i.mou.og.mou.p3  s3.rev.p1
# 0                    0.609456       0.22
# 1                    1.000000       0.38
# 2                    0.699592       0.11
# 3                    0.086617       5.18
# 4                    0.683105       0.10
#
# [5 rows x 111 columns]

# %%
df.shape
# Out:
# (25000, 111)

# %%
cols = df.columns
print(cols)
# Out:
# Index(['s6.new.rev.p2.m2', 's1.new.rev.m1', 's3.og.rev.4db.p5',
#        's3.new.rev.4db.p5', 's4.usg.ins.p2', 's4.og.unq.any.p2',
#        's2.rch.val.p6', 's1.og.rev.all.m1', 's8.new.rev.p6',
#        's4.loc.ic.ins.p1',
#        ...
#        'prop.og.mou.tot.mou.all.p6', 'prop.i2i.og.mou.p6', 's4.loc.ic.ins.p2',
#        's4.std.ic.ins.l14', 's4.low.blnc.ins.p4', 's3.og.rev.all.m2',
#        's3.new.rev.m2', 'prop.og.mou.any.p6', 'prop.loc.i2i.mou.og.mou.p3',
#        's3.rev.p1'],
#       dtype='object', length=111)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Columns: 111 entries, s6.new.rev.p2.m2 to s3.rev.p1
# dtypes: float64(80), int64(31)
# memory usage: 21.2 MB

# %%
df.describe()
# Out:
#        s6.new.rev.p2.m2  s1.new.rev.m1  s3.og.rev.4db.p5  s3.new.rev.4db.p5  \
# count      25000.000000   25000.000000      25000.000000       25000.000000
# mean          -0.003730     281.073083          4.890003           7.070194
# std            2.727916     276.075983          4.212452           6.318992
# min           -1.000000       0.000000          0.000000           0.000833
# 25%           -0.580000     101.563800          2.367288           3.318825
# 50%           -0.170000     204.859600          3.729944           5.231268
# 75%            0.280000     370.711650          5.993342           8.395736
# max          316.860000    5702.924300        153.221695         170.200441
#
#        s4.usg.ins.p2  s4.og.unq.any.p2  s2.rch.val.p6  s1.og.rev.all.m1  \
# count   25000.000000      25000.000000   25000.000000      25000.000000
# mean        5.460080         28.532520      72.208906        218.517937
# std         2.184444         28.061435      67.921490        231.321064
# min         0.000000          0.000000       0.000000          0.000000
# 25%         5.000000          9.000000      33.000000         74.420000
# 50%         7.000000         21.000000      52.260000        151.168500
# 75%         7.000000         39.000000      89.852500        284.265000
# max         7.000000        622.000000    2249.000000       3767.565000
#
#        s8.new.rev.p6  s4.loc.ic.ins.p1  ...  prop.og.mou.tot.mou.all.p6  \
# count   25000.000000      25000.000000  ...                25000.000000
# mean       -0.028327          3.254720  ...                    0.538407
# std         0.354573          1.193271  ...                    0.209203
# min        -5.090000          0.000000  ...                    0.000000
# 25%        -0.160000          3.000000  ...                    0.394227
# 50%        -0.020000          4.000000  ...                    0.539354
# 75%         0.110000          4.000000  ...                    0.682695
# max         5.000000          4.000000  ...                    1.000000
#
#        prop.i2i.og.mou.p6  s4.loc.ic.ins.p2  s4.std.ic.ins.l14  \
# count        25000.000000      25000.000000       25000.000000
# mean             0.485523          5.731280           1.797320
# std              0.271146          1.936848           3.048943
# min              0.000000          0.000000           0.000000
# 25%              0.274034          5.000000           0.000000
# 50%              0.476759          7.000000           0.000000
# 75%              0.694104          7.000000           2.000000
# max              1.000000          7.000000          14.000000
#
#        s4.low.blnc.ins.p4  s3.og.rev.all.m2  s3.new.rev.m2  \
# count        25000.000000      25000.000000   25000.000000
# mean             8.382160          8.008660      12.540182
# std              8.961016          6.152429      11.540611
# min              0.000000          0.000000       0.000000
# 25%              1.000000          4.207500       6.167500
# 50%              5.000000          6.345000       9.350000
# 75%             14.000000          9.830000      14.620000
# max             30.000000        171.780000     386.480000
#
#        prop.og.mou.any.p6  prop.loc.i2i.mou.og.mou.p3     s3.rev.p1
# count        25000.000000                25000.000000  25000.000000
# mean            53.594165                    0.483975      9.951366
# std             21.408486                    0.292349     17.648128
# min              0.000000                    0.000000      0.000000
# 25%             39.378142                    0.251304      1.970000
# 50%             53.976203                    0.477621      5.380000
# 75%             68.312416                    0.716538     11.400000
# max            100.000000                    1.000000    585.500000
#
# [8 rows x 111 columns]

# %%
'''bin_cols = []
for col in cols:
    if df[col].isin([0, 1]).all():
        bin_cols.append(col)
print(bin_cols)'''
# Out:
# 'bin_cols = []\nfor col in cols:\n    if df[col].isin([0, 1]).all():\n        bin_cols.append(col)\nprint(bin_cols)'

# %%
#df['target'] = df['target'].astype('object')

# %%
#df.describe(include='object')
# Out:
#         target
# count    25000
# unique       2
# top          0
# freq     17083

# %%
#churn - switch to other provider - 1
#not churn - remain active customer - 0

# %%
#check for NULL values
print(df.isnull().sum())
# Out:
# s6.new.rev.p2.m2              0
# s1.new.rev.m1                 0
# s3.og.rev.4db.p5              0
# s3.new.rev.4db.p5             0
# s4.usg.ins.p2                 0
#                              ..
# s3.og.rev.all.m2              0
# s3.new.rev.m2                 0
# prop.og.mou.any.p6            0
# prop.loc.i2i.mou.og.mou.p3    0
# s3.rev.p1                     0
# Length: 111, dtype: int64

# %%
print(df.isnull().sum().sum())
# Out:
# 0

# %%
#check for Duplicates
print(df.duplicated().sum())
# Out:
# 0

# %%
#checking columns with same values
same_val_cols = [col for col in df.columns if df[col].nunique() == 1]
print(len(same_val_cols))
print(same_val_cols)
#df = df.drop(same_val_cols, axis = 1)
# Out:
# 0
# []

# %%
#checking columns with more than 90% same value
same_val_cols = []
num_rows = len(df)
for col in df.columns:
    value_counts = df[col].value_counts()
    if value_counts.empty:
        continue
    most_common_value_count = value_counts.iloc[0]
    if most_common_value_count / num_rows >= 0.9:
        same_val_cols.append(col)
print(len(same_val_cols))
print(same_val_cols)
# Out:
# 0
# []

# %%
#unique values in each column
df.nunique()
# Out:
# s6.new.rev.p2.m2                584
# s1.new.rev.m1                 24134
# s3.og.rev.4db.p5              24969
# s3.new.rev.4db.p5             24980
# s4.usg.ins.p2                     8
#                               ...
# s3.og.rev.all.m2               2716
# s3.new.rev.m2                  3860
# prop.og.mou.any.p6            24819
# prop.loc.i2i.mou.og.mou.p3    23102
# s3.rev.p1                      3904
# Length: 111, dtype: int64

# %%
#checking for variables with all unique values
unique_value_vars = []
r = len(df)
c = df.columns
for col in c:
    if df[col].nunique() == r:
        unique_value_vars.append(col)
print(unique_value_vars)
# Out:
# []

# %%
for col in df.columns:
    if pd.api.types.is_numeric_dtype(df[col]):
        plt.figure(figsize=(8, 6))
        sns.boxplot(x=df[col])
        plt.title(f'Boxplot of {col}')
        plt.xlabel(col)
        plt.show()

# %%
plt.figure(figsize=(30,10))
df.boxplot()
plt.xticks(rotation=45, ha='right')
plt.title('Boxplots of all columns')
plt.tight_layout()
plt.show()

# %%
#using 3 sigma (standardization) approach for handling outliers
def handle_outliers(df):
    for column in df.columns.difference(['target']):
        mean = df[column].mean()
        std_dev = df[column].std()
        upper_bound = mean + 3 * std_dev
        lower_bound = mean - 3 * std_dev
        df[column] = np.where(df[column] < lower_bound, lower_bound, df[column])
        df[column] = np.where(df[column] > upper_bound, upper_bound, df[column])
    return df

df = handle_outliers(df)

# %%
#correlation between variables
print(df.corr())
# Out:
#                             s6.new.rev.p2.m2  s1.new.rev.m1  s3.og.rev.4db.p5  \
# s6.new.rev.p2.m2                    1.000000      -0.006901          0.034959
# s1.new.rev.m1                      -0.006901       1.000000          0.509467
# s3.og.rev.4db.p5                    0.034959       0.509467          1.000000
# s3.new.rev.4db.p5                   0.060425       0.547862          0.691440
# s4.usg.ins.p2                       0.390515       0.259553          0.080412
# ...                                      ...            ...               ...
# s3.og.rev.all.m2                   -0.073997       0.549958          0.916013
# s3.new.rev.m2                      -0.064726       0.559701          0.535320
# prop.og.mou.any.p6                  0.031495       0.234981          0.246439
# prop.loc.i2i.mou.og.mou.p3          0.048711       0.005926         -0.074112
# s3.rev.p1                           0.281255       0.329800          0.331506
#
#                             s3.new.rev.4db.p5  s4.usg.ins.p2  \
# s6.new.rev.p2.m2                     0.060425       0.390515
# s1.new.rev.m1                        0.547862       0.259553
# s3.og.rev.4db.p5                     0.691440       0.080412
# s3.new.rev.4db.p5                    1.000000       0.137475
# s4.usg.ins.p2                        0.137475       1.000000
# ...                                       ...            ...
# s3.og.rev.all.m2                     0.616086       0.113528
# s3.new.rev.m2                        0.923961       0.175825
# prop.og.mou.any.p6                   0.334881       0.083160
# prop.loc.i2i.mou.og.mou.p3           0.050261       0.098797
# s3.rev.p1                            0.313427       0.260634
#
#                             s4.og.unq.any.p2  s2.rch.val.p6  s1.og.rev.all.m1  \
# s6.new.rev.p2.m2                    0.258799       0.035819         -0.009553
# s1.new.rev.m1                       0.487123       0.361048          0.936892
# s3.og.rev.4db.p5                    0.242997       0.296150          0.561110
# s3.new.rev.4db.p5                   0.367440       0.376011          0.423486
# s4.usg.ins.p2                       0.559921       0.222370          0.264178
# ...                                      ...            ...               ...
# s3.og.rev.all.m2                    0.234316       0.328385          0.613384
# s3.new.rev.m2                       0.390577       0.397582          0.408631
# prop.og.mou.any.p6                  0.205517       0.122993          0.193666
# prop.loc.i2i.mou.og.mou.p3          0.076582      -0.079731         -0.042557
# s3.rev.p1                           0.294427       0.284154          0.326796
#
#                             s8.new.rev.p6  s4.loc.ic.ins.p1  ...  \
# s6.new.rev.p2.m2                 0.535116          0.205173  ...
# s1.new.rev.m1                   -0.106869          0.180245  ...
# s3.og.rev.4db.p5                -0.026211          0.011796  ...
# s3.new.rev.4db.p5               -0.037794          0.062679  ...
# s4.usg.ins.p2                    0.306577          0.526297  ...
# ...                                   ...               ...  ...
# s3.og.rev.all.m2                -0.081451          0.024429  ...
# s3.new.rev.m2                   -0.104464          0.091297  ...
# prop.og.mou.any.p6               0.000884         -0.211160  ...
# prop.loc.i2i.mou.og.mou.p3       0.043762          0.130528  ...
# s3.rev.p1                        0.226912          0.165037  ...
#
#                             prop.og.mou.tot.mou.all.p6  prop.i2i.og.mou.p6  \
# s6.new.rev.p2.m2                              0.031104            0.008421
# s1.new.rev.m1                                 0.253848           -0.012362
# s3.og.rev.4db.p5                              0.280909           -0.088307
# s3.new.rev.4db.p5                             0.356296            0.043683
# s4.usg.ins.p2                                 0.092855            0.016193
# ...                                                ...                 ...
# s3.og.rev.all.m2                              0.269781           -0.113909
# s3.new.rev.m2                                 0.342684            0.050258
# prop.og.mou.any.p6                            0.956916            0.112337
# prop.loc.i2i.mou.og.mou.p3                    0.061705            0.784837
# s3.rev.p1                                     0.138667           -0.045692
#
#                             s4.loc.ic.ins.p2  s4.std.ic.ins.l14  \
# s6.new.rev.p2.m2                    0.209982           0.049908
# s1.new.rev.m1                       0.187866           0.237568
# s3.og.rev.4db.p5                    0.013364           0.240256
# s3.new.rev.4db.p5                   0.064110           0.188449
# s4.usg.ins.p2                       0.552532           0.143278
# ...                                      ...                ...
# s3.og.rev.all.m2                    0.025618           0.259162
# s3.new.rev.m2                       0.092940           0.177742
# prop.og.mou.any.p6                 -0.230123          -0.034531
# prop.loc.i2i.mou.og.mou.p3          0.137230          -0.114965
# s3.rev.p1                           0.163149           0.171714
#
#                             s4.low.blnc.ins.p4  s3.og.rev.all.m2  \
# s6.new.rev.p2.m2                     -0.063619         -0.073997
# s1.new.rev.m1                        -0.081687          0.549958
# s3.og.rev.4db.p5                     -0.139923          0.916013
# s3.new.rev.4db.p5                     0.180065          0.616086
# s4.usg.ins.p2                        -0.379504          0.113528
# ...                                        ...               ...
# s3.og.rev.all.m2                     -0.189501          1.000000
# s3.new.rev.m2                         0.216843          0.557874
# prop.og.mou.any.p6                   -0.020984          0.235457
# prop.loc.i2i.mou.og.mou.p3            0.070085         -0.087706
# s3.rev.p1                            -0.103392          0.338701
#
#                             s3.new.rev.m2  prop.og.mou.any.p6  \
# s6.new.rev.p2.m2                -0.064726            0.031495
# s1.new.rev.m1                    0.559701            0.234981
# s3.og.rev.4db.p5                 0.535320            0.246439
# s3.new.rev.4db.p5                0.923961            0.334881
# s4.usg.ins.p2                    0.175825            0.083160
# ...                                   ...                 ...
# s3.og.rev.all.m2                 0.557874            0.235457
# s3.new.rev.m2                    1.000000            0.326079
# prop.og.mou.any.p6               0.326079            1.000000
# prop.loc.i2i.mou.og.mou.p3       0.063598            0.096616
# s3.rev.p1                        0.289273            0.127357
#
#                             prop.loc.i2i.mou.og.mou.p3  s3.rev.p1
# s6.new.rev.p2.m2                              0.048711   0.281255
# s1.new.rev.m1                                 0.005926   0.329800
# s3.og.rev.4db.p5                             -0.074112   0.331506
# s3.new.rev.4db.p5                             0.050261   0.313427
# s4.usg.ins.p2                                 0.098797   0.260634
# ...                                                ...        ...
# s3.og.rev.all.m2                             -0.087706   0.338701
# s3.new.rev.m2                                 0.063598   0.289273
# prop.og.mou.any.p6                            0.096616   0.127357
# prop.loc.i2i.mou.og.mou.p3                    1.000000  -0.006208
# s3.rev.p1                                    -0.006208   1.000000
#
# [111 rows x 111 columns]

# %%
df[['ds.usg.p6', 'ds.og.usg.p4','target']].corr()
# Out:
#               ds.usg.p6  ds.og.usg.p4    target
# ds.usg.p6      1.000000      0.963299  0.368604
# ds.og.usg.p4   0.963299      1.000000  0.374503
# target         0.368604      0.374503  1.000000

# %%
plt.figure(figsize=(25, 18))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
#removing highly correlated columns Threshold = 0.8
corr_mat = df.corr().abs()
cols_to_remove = set()
threshold = 0.8
for col in corr_mat.columns:
    if col in cols_to_remove:
        continue
    correlated_cols = corr_mat[col][(corr_mat[col] > threshold) & (corr_mat[col].index != col)].index.tolist()
    cols_to_remove.update(correlated_cols)
if cols_to_remove:
    df.drop(columns=cols_to_remove, inplace=True)

# %%
df.shape
# Out:
# (25000, 41)

# %%
print(df.columns)
# Out:
# Index(['s6.new.rev.p2.m2', 's1.new.rev.m1', 's3.og.rev.4db.p5',
#        's3.new.rev.4db.p5', 's4.usg.ins.p2', 's4.og.unq.any.p2',
#        's2.rch.val.p6', 's8.new.rev.p6', 's4.loc.ic.ins.p1', 's8.mbl.p2',
#        's7.s4.day.no.mou.p2.p4', 's3.new.rev.p3', 's7.s5.s4.day.nomou.p4',
#        's8.og.rev.p3', 's8.ic.mou.all.p3', 'target', 's6.rtd.mou.p2.m2',
#        's1.new.rev.p2', 's1.og.hom.mou.p1', 's7.rev.p2.p6', 's3.og.rev.all.p1',
#        's7.new.rev.p3.p6', 'ds.usg.p6', 's3.new.rev.p1', 's5.rev.p1',
#        's4.loc.og.ins.p1', 'prop.og.mou.any.p2', 's4.low.blnc.ins.p3',
#        's7.rtd.mou.l21.p6', 's8.rtd.mou.p3', 's4.dec.ins.l14',
#        's8.og.mou.all.p6', 's7.rtd.mou.m1.m2', 's7.s5.s4.day.nomou.p3',
#        's1.new.rev.m2', 's4.rch.val.gt.30.p2', 's4.std.ins.l14',
#        's4.loc.ins.l14', 's4.data.ins.l14', 'prop.loc.i2i.mou.og.mou.p6',
#        'prop.og.mou.tot.mou.all.p6'],
#       dtype='object')

# %%
#Multicollinearity VIF > 20
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
X = df.drop('target',axis=1)
vif["Feature"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
high_vif = vif[vif['VIF'] > 20]
print(len(high_vif))
print(high_vif.sort_values(by = 'VIF', ascending = False))
# Out:
# 10
#                        Feature        VIF
# 36              s4.loc.ins.l14  78.680555
# 4                s4.usg.ins.p2  47.801860
# 29              s4.dec.ins.l14  38.081067
# 33               s1.new.rev.m2  31.728058
# 20            s7.new.rev.p3.p6  28.312769
# 27           s7.rtd.mou.l21.p6  27.627121
# 8             s4.loc.ic.ins.p1  26.543303
# 24            s4.loc.og.ins.p1  21.423763
# 16               s1.new.rev.p2  20.131413
# 39  prop.og.mou.tot.mou.all.p6  20.122214

# %%
df = df.drop(high_vif['Feature'],axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   s6.new.rev.p2.m2            25000 non-null  float64
#  1   s1.new.rev.m1               25000 non-null  float64
#  2   s3.og.rev.4db.p5            25000 non-null  float64
#  3   s3.new.rev.4db.p5           25000 non-null  float64
#  4   s4.og.unq.any.p2            25000 non-null  float64
#  5   s2.rch.val.p6               25000 non-null  float64
#  6   s8.new.rev.p6               25000 non-null  float64
#  7   s8.mbl.p2                   25000 non-null  float64
#  8   s7.s4.day.no.mou.p2.p4      25000 non-null  float64
#  9   s3.new.rev.p3               25000 non-null  float64
#  10  s7.s5.s4.day.nomou.p4       25000 non-null  float64
#  11  s8.og.rev.p3                25000 non-null  float64
#  12  s8.ic.mou.all.p3            25000 non-null  float64
#  13  target                      25000 non-null  int64
#  14  s6.rtd.mou.p2.m2            25000 non-null  float64
#  15  s1.og.hom.mou.p1            25000 non-null  float64
#  16  s7.rev.p2.p6                25000 non-null  float64
#  17  s3.og.rev.all.p1            25000 non-null  float64
#  18  ds.usg.p6                   25000 non-null  float64
#  19  s3.new.rev.p1               25000 non-null  float64
#  20  s5.rev.p1                   25000 non-null  float64
#  21  prop.og.mou.any.p2          25000 non-null  float64
#  22  s4.low.blnc.ins.p3          25000 non-null  float64
#  23  s8.rtd.mou.p3               25000 non-null  float64
#  24  s8.og.mou.all.p6            25000 non-null  float64
#  25  s7.rtd.mou.m1.m2            25000 non-null  float64
#  26  s7.s5.s4.day.nomou.p3       25000 non-null  float64
#  27  s4.rch.val.gt.30.p2         25000 non-null  float64
#  28  s4.std.ins.l14              25000 non-null  float64
#  29  s4.data.ins.l14             25000 non-null  float64
#  30  prop.loc.i2i.mou.og.mou.p6  25000 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 5.9 MB

# %%
df.to_csv('cleaned_telecom_data1.csv', index=False)
